# %% [markdown]
# ### Assignment -1 :
#  Temperature Check Problem

# %%
Temp =float(input(" The Current Temperature °C: "))


if Temp < 10:
    print("It's cool!") 

elif Temp > 10 and Temp < 25:
    print("It's cool outside!") 

else:
    print("It's hot outside!")
# Out:
#  The Current Temperature °C: 21
# It's cool outside!

# %% [markdown]
# ### Assignment -2 :
# ATM Withdrawal System

# %%
"""
Actual credentials;
withdraw balance= 20,000
"""
manu =input("""
Hi there!wellcame to ATM 
please chose
1.Enter 1 for account balance
2.Enter 2 for withdraw
3.Exit                       
""")
withdraw_balance = "20,000"

if manu=="1":
    print("account balance ")

elif manu=="2":
    print("Whitdrow") 
    a =input("Enter your withdraw amount: ") 
    if  a<=withdraw_balance :
        print("Transaction Successful")

    else:
        print("Insufficient Balance") 

else:
    print("Exit")
# Out:
# Hi there!wellcame to ATM
# please chose
# 1.Enter 1 for account balance
# 2.Enter 2 for withdraw
# 3.Exit
# 2
# Whitdrow
# Enter your withdraw amount: 14000
# Transaction Successful

# %% [markdown]
# ### Assignment -3 :
# Student Grade based on:

# %%
mark = int(input("Enter the number: "))

if mark>=90 and mark<=100:
    print("Grade is A+")

elif mark>=80 and mark<=89:
    print("Grade is A") 

elif mark>=70 and mark<=79:
    print("Grade is B") 

elif mark>=60 and mark<=69:
    print("Grade is C") 

else:
    print("Fail...!!")
# Out:
# Enter the number: 71
# Grade is B

# %% [markdown]
# ### Assignment -4 :
# Bus Ticket Discount:

# %%
manu =int(input("""
Hi there!wellcame to Bus Couter.
We have a discount for some of our passengers.             
please 
1.Enter Your Age    
"""))

if manu<5:
    print("Free ticket!!")

elif manu>=5 and manu<=18:
    print("50% Discount!!") 

elif manu<=60:
    print("30% Discount!!") 

else:
    print("Full price!!")
# Out:
# Hi there!wellcame to Bus Couter.
# We have a discount for some of our passengers.
# please
# 1.Enter Your Age
# 34
# 30% Discount!!

# %% [markdown]
# ### Assignment -5 :
# Restaurant Bill With Discount

# %%
manu = float(input("Total Bill Amount: "))

if manu >1000:
    print("10% Discount")

else:
    print("No Discount!!")
# Out:
# Total Bill Amount: 2398
# 10% Discount

# %% [markdown]
# ### Assignment -6 :
# Login Authentication

# %%
"""
Actual credentials;
usename = admin
password = 12345
"""
email = input("Enter the usename: ")
password = input("Enter the password: ")

actual_usename= "admin"
actual_password="12345"

if email == actual_usename and password == actual_password:
    print("Login Successfull")

else:
    print("Invalid Credentials!!")
# Out:
# Enter the usename: admin
# Enter the password: 12345
# Login Successfull

# %% [markdown]
# ### Assignment -7 :
# Traffic Light System

# %%
manu =input("Enter the colour:")
colour1 ="red"
colour2 ="yellow"
colour3 ="green"

if manu==colour1:
    print("stop!!")

elif manu==colour2:
    print("Ready to go!!")

elif manu==colour3:
    print("Go!!")

else:
    print("Invalid Colour")
# Out:
# Enter the colour:green
# Go!!

# %% [markdown]
# ### Assignment -8 :
# Leap Year Checker

# %%
year =int(input("Enter the year: "))

if year % 400==0:
    print("Leap Year")

elif year % 4==0 and year % 100!=0:
    print("Leap Year")
    
else:
    print(" Not a Leap Year!!")
# Out:
# Enter the year: 2024
# Leap Year

# %% [markdown]
# ### Assignment -9 :
# Job Eligible Cheaker

# %%
age =int(input("""
Hi there!wellcame to Inception BD            
please 
1.Enter Your Age:                
"""))
qual =input("Enter Your Qualification: ")

Qualification ="Graduate"

if  age >= 18 and qual==Qualification:
    print("Eligible for job!!")

else:
    print("Not Eligible !!")
# Out:
# Hi there!wellcame to Inception BD
# please
# 1.Enter Your Age:
# 24
# Enter Your Qualification: Graduate
# Eligible for job!!

# %% [markdown]
# ### Assignment -10 :
# Electricity Bill Calculator

# %%
units =int(input("Enter num of unit cons : "))

if units<=100:
    print("5 BDT Per unit !!")

elif units>=101 and units<=200:
    print("7 BDT Per unit!!") 

else:
    print(" 10 BDT Per unit!!")
# Out:
# Enter num of unit cons : 165
# 7 BDT Per unit!!
